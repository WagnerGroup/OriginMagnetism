# %%
import seaborn as sns
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
df = pd.read_json('allobdm.json')

# %%
# FM Up matrices
fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][5], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][9], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax3 = plt.subplot("333",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][2], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax4 = plt.subplot("334",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][0], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax5 = plt.subplot("335",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][10], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax6 = plt.subplot("337")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][7], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax7 = plt.subplot("338")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][4], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
fig.tight_layout()
plt.show()

# %%
#FM Down

fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][5], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][9], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax3 = plt.subplot("333",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][2], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax4 = plt.subplot("334",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][0], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax5 = plt.subplot("335",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][10], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax6 = plt.subplot("337")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][7], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax7 = plt.subplot("338")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][4], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
fig.tight_layout()
plt.show()

# %%
# AFM Up matrices
fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][12], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][3], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax3 = plt.subplot("333",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][13], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax4 = plt.subplot("334",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][11], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax5 = plt.subplot("335",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][8], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax6 = plt.subplot("337")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][6], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax7 = plt.subplot("338")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][1], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
fig.tight_layout()
plt.show()

# %%
# AFM Down matrices
fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][12], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][3], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax3 = plt.subplot("333",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][13], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax4 = plt.subplot("334",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][11], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax5 = plt.subplot("335",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][8], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax6 = plt.subplot("337")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][6], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
ax7 = plt.subplot("338")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][1], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5)
fig.tight_layout()
plt.show()
