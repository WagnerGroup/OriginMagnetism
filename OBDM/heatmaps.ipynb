# %%
import seaborn as sns
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
#plt.rc('text', usetex=True)
#plt.rc('font', family='serif')

# %%
df = pd.read_json('allobdm.json')

# %%
# FM Up matrices
fig = plt.figure()
ticks = np.array(['Mn','Mn','Mn','Mn','Mn','O','O','O','Mn','Mn','Mn','Mn','Mn'])
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][5], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax1.axvline(5, 0, 2, linewidth=0.5, c='black')
ax1.axvline(8, 0, 2, linewidth=0.5, c='black')
ax1.axhline(5, 0, 2, linewidth=0.5, c='black')
ax1.axhline(8, 0, 2, linewidth=0.5, c='black')
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][9], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax2.axvline(5, 0, 2, linewidth=0.5, c='black')
ax2.axvline(8, 0, 2, linewidth=0.5, c='black')
ax2.axhline(5, 0, 2, linewidth=0.5, c='black')
ax2.axhline(8, 0, 2, linewidth=0.5, c='black')
ax3 = plt.subplot("334",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][2], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax3.axvline(5, 0, 2, linewidth=0.5, c='black')
ax3.axvline(8, 0, 2, linewidth=0.5, c='black')
ax3.axhline(5, 0, 2, linewidth=0.5, c='black')
ax3.axhline(8, 0, 2, linewidth=0.5, c='black')
ax4 = plt.subplot("335",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][0], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax4.axvline(5, 0, 2, linewidth=0.5, c='black')
ax4.axvline(8, 0, 2, linewidth=0.5, c='black')
ax4.axhline(5, 0, 2, linewidth=0.5, c='black')
ax4.axhline(8, 0, 2, linewidth=0.5, c='black')
ax5 = plt.subplot("337",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][10], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax5.axvline(5, 0, 2, linewidth=0.5, c='black')
ax5.axvline(8, 0, 2, linewidth=0.5, c='black')
ax5.axhline(5, 0, 2, linewidth=0.5, c='black')
ax5.axhline(8, 0, 2, linewidth=0.5, c='black')
ax6 = plt.subplot("338")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][7], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax6.axvline(5, 0, 2, linewidth=0.5, c='black')
ax6.axvline(8, 0, 2, linewidth=0.5, c='black')
ax6.axhline(5, 0, 2, linewidth=0.5, c='black')
ax6.axhline(8, 0, 2, linewidth=0.5, c='black')
ax7 = plt.subplot("339")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][4], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax7.axvline(5, 0, 2, linewidth=0.5, c='black')
ax7.axvline(8, 0, 2, linewidth=0.5, c='black')
ax7.axhline(5, 0, 2, linewidth=0.5, c='black')
ax7.axhline(8, 0, 2, linewidth=0.5, c='black')
plt.setp(ax7.get_yticklabels(), visible=False)
plt.setp(ax6.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)
fig.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:143: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if xticklabels == []:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:151: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if yticklabels == []:

# %%
#FM Down

fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][5], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax1.axvline(5, 0, 2, linewidth=0.5, c='black')
ax1.axvline(8, 0, 2, linewidth=0.5, c='black')
ax1.axhline(5, 0, 2, linewidth=0.5, c='black')
ax1.axhline(8, 0, 2, linewidth=0.5, c='black')
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][9], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax2.axvline(5, 0, 2, linewidth=0.5, c='black')
ax2.axvline(8, 0, 2, linewidth=0.5, c='black')
ax2.axhline(5, 0, 2, linewidth=0.5, c='black')
ax2.axhline(8, 0, 2, linewidth=0.5, c='black')
ax3 = plt.subplot("334",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][2], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax3.axvline(5, 0, 2, linewidth=0.5, c='black')
ax3.axvline(8, 0, 2, linewidth=0.5, c='black')
ax3.axhline(5, 0, 2, linewidth=0.5, c='black')
ax3.axhline(8, 0, 2, linewidth=0.5, c='black')
ax4 = plt.subplot("335",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][0], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax4.axvline(5, 0, 2, linewidth=0.5, c='black')
ax4.axvline(8, 0, 2, linewidth=0.5, c='black')
ax4.axhline(5, 0, 2, linewidth=0.5, c='black')
ax4.axhline(8, 0, 2, linewidth=0.5, c='black')
ax5 = plt.subplot("337",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][10], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax5.axvline(5, 0, 2, linewidth=0.5, c='black')
ax5.axvline(8, 0, 2, linewidth=0.5, c='black')
ax5.axhline(5, 0, 2, linewidth=0.5, c='black')
ax5.axhline(8, 0, 2, linewidth=0.5, c='black')
ax6 = plt.subplot("338")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][7], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax6.axvline(5, 0, 2, linewidth=0.5, c='black')
ax6.axvline(8, 0, 2, linewidth=0.5, c='black')
ax6.axhline(5, 0, 2, linewidth=0.5, c='black')
ax6.axhline(8, 0, 2, linewidth=0.5, c='black')
ax7 = plt.subplot("339")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][4], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax7.axvline(5, 0, 2, linewidth=0.5, c='black')
ax7.axvline(8, 0, 2, linewidth=0.5, c='black')
ax7.axhline(5, 0, 2, linewidth=0.5, c='black')
ax7.axhline(8, 0, 2, linewidth=0.5, c='black')
plt.setp(ax7.get_yticklabels(), visible=False)
plt.setp(ax6.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)
fig.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:143: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if xticklabels == []:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:151: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if yticklabels == []:

# %%
# AFM Up matrices
fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][12], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax1.axvline(5, 0, 2, linewidth=0.5, c='black')
ax1.axvline(8, 0, 2, linewidth=0.5, c='black')
ax1.axhline(5, 0, 2, linewidth=0.5, c='black')
ax1.axhline(8, 0, 2, linewidth=0.5, c='black')
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][3], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax2.axvline(5, 0, 2, linewidth=0.5, c='black')
ax2.axvline(8, 0, 2, linewidth=0.5, c='black')
ax2.axhline(5, 0, 2, linewidth=0.5, c='black')
ax2.axhline(8, 0, 2, linewidth=0.5, c='black')
ax3 = plt.subplot("334",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][13], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax3.axvline(5, 0, 2, linewidth=0.5, c='black')
ax3.axvline(8, 0, 2, linewidth=0.5, c='black')
ax3.axhline(5, 0, 2, linewidth=0.5, c='black')
ax3.axhline(8, 0, 2, linewidth=0.5, c='black')
ax4 = plt.subplot("335",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][11], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax4.axvline(5, 0, 2, linewidth=0.5, c='black')
ax4.axvline(8, 0, 2, linewidth=0.5, c='black')
ax4.axhline(5, 0, 2, linewidth=0.5, c='black')
ax4.axhline(8, 0, 2, linewidth=0.5, c='black')
ax5 = plt.subplot("337",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][8], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax5.axvline(5, 0, 2, linewidth=0.5, c='black')
ax5.axvline(8, 0, 2, linewidth=0.5, c='black')
ax5.axhline(5, 0, 2, linewidth=0.5, c='black')
ax5.axhline(8, 0, 2, linewidth=0.5, c='black')
ax6 = plt.subplot("338")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][6], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax6.axvline(5, 0, 2, linewidth=0.5, c='black')
ax6.axvline(8, 0, 2, linewidth=0.5, c='black')
ax6.axhline(5, 0, 2, linewidth=0.5, c='black')
ax6.axhline(8, 0, 2, linewidth=0.5, c='black')
ax7 = plt.subplot("339")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['upmatrix'][1], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax7.axvline(5, 0, 2, linewidth=0.5, c='black')
ax7.axvline(8, 0, 2, linewidth=0.5, c='black')
ax7.axhline(5, 0, 2, linewidth=0.5, c='black')
ax7.axhline(8, 0, 2, linewidth=0.5, c='black')
plt.setp(ax7.get_yticklabels(), visible=False)
plt.setp(ax6.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)

fig.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:143: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if xticklabels == []:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:151: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if yticklabels == []:

# %%
# AFM Down matrices
fig = plt.figure()
ax1 = plt.subplot(3,3,1)
ax1.set_title("0")
ax1.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][12], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax1.axvline(5, 0, 2, linewidth=0.5, c='black')
ax1.axvline(8, 0, 2, linewidth=0.5, c='black')
ax1.axhline(5, 0, 2, linewidth=0.5, c='black')
ax1.axhline(8, 0, 2, linewidth=0.5, c='black')
ax2 = plt.subplot("332",sharex=ax1, sharey=ax1)
ax2.set_title("15")
ax2.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][3], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax2.axvline(5, 0, 2, linewidth=0.5, c='black')
ax2.axvline(8, 0, 2, linewidth=0.5, c='black')
ax2.axhline(5, 0, 2, linewidth=0.5, c='black')
ax2.axhline(8, 0, 2, linewidth=0.5, c='black')
ax3 = plt.subplot("334",sharex=ax1, sharey=ax1)
ax3.set_title("30")
ax3.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][13], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax3.axvline(5, 0, 2, linewidth=0.5, c='black')
ax3.axvline(8, 0, 2, linewidth=0.5, c='black')
ax3.axhline(5, 0, 2, linewidth=0.5, c='black')
ax3.axhline(8, 0, 2, linewidth=0.5, c='black')
ax4 = plt.subplot("335",sharex = ax1)
ax4.set_title("45")
ax4.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][11], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax4.axvline(5, 0, 2, linewidth=0.5, c='black')
ax4.axvline(8, 0, 2, linewidth=0.5, c='black')
ax4.axhline(5, 0, 2, linewidth=0.5, c='black')
ax4.axhline(8, 0, 2, linewidth=0.5, c='black')
ax5 = plt.subplot("337",sharex = ax1)
ax5.set_title("60")
ax5.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][8], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax5.axvline(5, 0, 2, linewidth=0.5, c='black')
ax5.axvline(8, 0, 2, linewidth=0.5, c='black')
ax5.axhline(5, 0, 2, linewidth=0.5, c='black')
ax5.axhline(8, 0, 2, linewidth=0.5, c='black')
ax6 = plt.subplot("338")
ax6.set_title("75")
ax6.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][6], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax6.axvline(5, 0, 2, linewidth=0.5, c='black')
ax6.axvline(8, 0, 2, linewidth=0.5, c='black')
ax6.axhline(5, 0, 2, linewidth=0.5, c='black')
ax6.axhline(8, 0, 2, linewidth=0.5, c='black')
ax7 = plt.subplot("339")
ax7.set_title("90")
ax7.tick_params(axis='both', which='major', labelsize=8)
sns.heatmap(df['downmatrix'][1], vmin=0, vmax=1,cmap="YlGnBu", linewidths=.5,xticklabels=ticks,yticklabels=ticks)
ax7.axvline(5, 0, 2, linewidth=0.5, c='black')
ax7.axvline(8, 0, 2, linewidth=0.5, c='black')
ax7.axhline(5, 0, 2, linewidth=0.5, c='black')
ax7.axhline(8, 0, 2, linewidth=0.5, c='black')
plt.setp(ax7.get_yticklabels(), visible=False)
plt.setp(ax6.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)
fig.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:143: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if xticklabels == []:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/seaborn/matrix.py:151: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if yticklabels == []:
